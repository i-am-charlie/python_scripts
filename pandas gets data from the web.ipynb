# %%
# %%file foo.txt
#
# for i in range (10):
#     print 'foo' * i
# Out:
# Writing foo.txt

# %%
load foo.txt

# %%
for i in range (10):
    print 'foo' * i
# Out:
# foo
# foofoo
# foofoofoo
# foofoofoofoo
# foofoofoofoofoo
# foofoofoofoofoofoo
# foofoofoofoofoofoofoo
# foofoofoofoofoofoofoofoo
# foofoofoofoofoofoofoofoofoo

# %%
print 'okay then'
# Out:
# okay then

# %% [markdown]
# now, let's see if i can use the pandas package to read data from an online url....
#
# let's see how it goes....

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib2
import pandas.io.data as web
import datetime as dt

# %%
# %matplotlib inline

ticker_list = {'INTC': 'Intel',
               'MSFT': 'Microsoft',
               'IBM': 'IBM',
               'BHP': 'BHP',
               'RSH': 'RadioShack',
               'TM': 'Toyota',
               'AAPL': 'Apple',
               'AMZN': 'Amazon',
               'BA': 'Boeing',
               'QCOM': 'Qualcomm',
               'KO': 'Coca-Cola',
               'GOOG': 'Google',
               'SNE': 'Sony',
               'PTR': 'PetroChina'}

start, end = dt.datetime(2014, 1, 1), dt.datetime(2014, 1, 31)

price_change = {}

for ticker in ticker_list:
    prices = web.DataReader(ticker, 'yahoo', start, end)
    closing_prices = prices['Close']
    change = 100 * (closing_prices[-1] - closing_prices[0]) / closing_prices[0]
    name = ticker_list[ticker]
    price_change[name] = change

# %%
pc = pd.Series(price_change)
pc
# Out:
# Amazon        -9.870091
# Apple         -9.496863
# BHP           -4.537991
# Boeing        -8.348577
# Coca-Cola     -6.984752
# Google         6.095479
# IBM           -4.770118
# Intel         -4.846840
# Microsoft      1.829925
# PetroChina   -11.087420
# Qualcomm       1.227496
# RadioShack    -9.090909
# Sony          -8.216783
# Toyota        -4.866120
# dtype: float64

# %%
pc.sort()

# %%
fig, ax = plt.subplots()
pc.plot(kind='bar', ax=ax)
plt.show()

# %%
start, end = dt.datetime(2013, 11, 1), dt.datetime(2013, 12, 31)

price_change = {}

for ticker in ticker_list:
    prices = web.DataReader(ticker, 'yahoo', start, end)
    closing_prices = prices['Close']
    change = 100 * (closing_prices[-1] - closing_prices[0]) / closing_prices[0]
    name = ticker_list[ticker]
    price_change[name] = change
    
pc2 = pd.Series(price_change)
pc2.sort()
fig,ax = plt.subplots()
pc.plot(kind='bar', ax=ax)
fig, ax = plt.subplots()
pc2.plot(kind = 'bar', ax=ax)
plt.show()

# %% [markdown]
# very nice :-)

# %% [markdown]
# yes...

# %% [markdown]
# very nice, indeed...
